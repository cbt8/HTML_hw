# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw = pd.read_csv('./cities.csv')

# %%
rawdf = pd.DataFrame(raw)

# %%
rawdf
# Out:
#      City_ID                City  Cloudiness Country        Date  Humidity  \
# 0          0        jacareacanga           0      BR  1528902000        62
# 1          1          kaitangata         100      NZ  1528905304        94
# 2          2            goulburn          20      AU  1528905078        91
# 3          3                lata          76      IN  1528905305        89
# 4          4          chokurdakh           0      RU  1528905306        88
# 5          5            martyush          92      RU  1528905306        94
# 6          6              hobart          20      AU  1528902000        87
# 7          7         broken hill           0      AU  1528905311        88
# 8          8           harnosand           0      SE  1528903200        44
# 9          9           tuatapere           0      NZ  1528905312       100
# 10        10        puerto ayora          90      EC  1528902000        69
# ...

# %%
cloudycountrydf = rawdf[['Cloudiness', 'Country']].sort_values(['Cloudiness'])

# %%
cloudycountrydf = cloudycountrydf.reset_index()

# %%
cloudycountrydf = cloudycountrydf.dropna()

cloudycountrydf['Country'].unique()
# Out:
# array(['BR', 'NE', 'RU', 'CD', 'CL', 'PF', 'BG', 'TD', 'IQ', 'ML', 'ES',
#        'BW', 'CR', 'IN', 'BF', 'IT', 'ZA', 'KZ', 'SO', 'VE', 'AU', 'AR',
#        'AO', 'PK', 'TZ', 'TN', 'CO', 'PY', 'CI', 'EE', 'MW', 'CN', 'US',
#        'FI', 'ZM', 'DZ', 'JP', 'CG', 'OM', 'MX', 'UZ', 'FR', 'MG', 'AE',
#        'SE', 'NZ', 'PE', 'EG', 'CV', 'CA', 'MN', 'DK', 'NC', 'MV', 'ID',
#        'KR', 'MR', 'CY', 'NG', 'GB', 'PT', 'BB', 'IR', 'GA', 'LY', 'CF',
#        'GL', 'PG', 'VN', 'PH', 'DO', 'VG', 'SA', 'CK', 'NO', 'GR', 'BM',
#        'MK', 'GW', 'KY', 'SV', 'TH', 'AF', 'TG', 'UY', 'KI', 'SB', 'VU',
#        'UG', 'HR', 'DE', 'IS', 'MU', 'GY', 'BN', 'HN', 'TT', 'IE', 'TL',
#        'NU', 'CH', 'NP', 'ET', 'TM', 'HT', 'BS', 'BD', 'EC', 'BO', 'PW',
#        'MM', 'FO', 'LK', 'GF', 'MZ'], dtype=object)

# %%
cloudycountrydf['Country'].value_counts()
# Out:
# RU    78
# US    39
# CA    34
# BR    28
# AU    22
# CN    13
# ID    13
# MX    12
# PH    12
# AR    11
# FR    10
# IN    10
# ZA     9
# NZ     9
# JP     8
# PG     8
# CL     8
# PT     7
# ES     7
# GB     7
# GL     7
# CO     7
# NO     7
# CD     6
# PE     6
# NG     6
# MG     6
# PK     6
# KZ     5
# UY     5
#       ..
# GW     1
# TL     1
# NU     1
# TM     1
# MW     1
# CK     1
# TT     1
# MZ     1
# SA     1
# BO     1
# CG     1
# AE     1
# CV     1
# BD     1
# UG     1
# VG     1
# MM     1
# GR     1
# DO     1
# LY     1
# CR     1
# PW     1
# HR     1
# KY     1
# EG     1
# MN     1
# SB     1
# KI     1
# MK     1
# GF     1
# Name: Country, Length: 115, dtype: int64

# %%
newdf = cloudycountrydf[['Country']]
newdf['Mean Cloudiness'] = cloudycountrydf['Cloudiness'].mean()
# Out:
# C:\Users\CliffConda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in range(len(newdf['Country'])):
    newdf['Mean Cloudiness'][i] =
# Out:
# C:\Users\CliffConda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in setitem(key, value)
#     885             try:
# --> 886                 self._set_with_engine(key, value)
#     887                 return
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#     944         try:
# --> 945             self.index._engine.set_value(values, key, value)
#     946             return
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# ...

# %%
x = cloudycountrydf.groupby(['Country']).mean()

# %%
x= x.reset_index()

# %%
 clouddf = x.sort_values('Cloudiness', ascending=False)

# %%
plt.scatter(clouddf['Country'][:10], clouddf['Cloudiness'][:10])
# Out:
# <BarContainer object of 10 artists>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-7d1e58bfa4f8> in <module>()
#       1 #for i in range(len(newdf)):
# ----> 2 newdf['Mean Cloudiness'] = x.loc[(newdf['Country'] == x['Country'])]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1185
#    1186         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1187             raise ValueError("Can only compare identically-labeled "
#    1188                              "Series objects")
#    1189
#
# ValueError: Can only compare identically-labeled Series objects

# %%
x
# Out:
# 'dfsfadfa'

# %%
x = 'dfsfadfa'

# %%
x[1]
# Out:
# 'f'
